# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('../data/sample/students.csv')

# Explore the data
print("Head:\n", df.head())
print("\nShape:", df.shape)
print("\nColumns:", df.columns)
print("\nData Types:\n", df.dtypes)
# Out:
# Head:
#     id  name  age  gpa
# 0   1   Ram   20  3.2
# 1   2  Sita   21  3.8
# 2   3  Hari   22  3.1
# 3   4  Gita   20  3.9
#
# Shape: (4, 4)
#
# Columns: Index(['id', 'name', 'age', 'gpa'], dtype='str')
#
# Data Types:
#  id        int64
# name        str
# age       int64
# gpa     float64
# dtype: object
