# %%
import sys
sys.path.append('..')
from app.tools.data_loader import DatasetLoader

# %%
loader = DatasetLoader()
df = loader.load("../data/sample/students.csv")
df.head()
# Out:
# 2026-06-14 10:24:41,399 - DataScienceAgent - INFO - Attempting to load dataset from ../data/sample/students.csv
# 2026-06-14 10:24:41,420 - DataScienceAgent - INFO - Dataset loaded 4 rows successfully from ../data/sample/students.csv
#    id  name  age  gpa
# 0   1   Ram   20  3.2
# 1   2  Sita   21  3.8
# 2   3  Hari   22  3.1
# 3   4  Gita   20  3.9

# %%
metadata = loader.get_metadata()
metadata
# Out:
# 2026-06-14 10:25:00,398 - DataScienceAgent - INFO - Metadata retrieved for dataset: {'row_count': 4, 'column_count': 4, 'column_names': ['id', 'name', 'age', 'gpa'], 'file_path': '../data/sample/students.csv', 'data_types': {'id': 'int64', 'name': 'str', 'age': 'int64', 'gpa': 'float64'}}
# {'row_count': 4,
#  'column_count': 4,
#  'column_names': ['id', 'name', 'age', 'gpa'],
#  'file_path': '../data/sample/students.csv',
#  'data_types': {'id': 'int64',
#   'name': 'str',
#   'age': 'int64',
#   'gpa': 'float64'}}

# %%
loader.load("data/sample/ghost.csv")
# Out:
# 2026-06-14 10:25:19,868 - DataScienceAgent - INFO - Attempting to load dataset from data/sample/ghost.csv
# 2026-06-14 10:25:19,869 - DataScienceAgent - ERROR - The file data/sample/ghost.csv does not exist.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 loader.load("data/sample/ghost.csv")
#
# File c:\Users\suluc\Desktop\autonomous-data-science-agent\notebooks\..\app\tools\data_loader.py:41, in DatasetLoader.load(self, path)
#      38 self.filepath = path
#      40 # Validate the file before loading
# ---> 41 self.validate_file(self.filepath)
#      42 self.data = pd.read_csv(self.filepath)
#      44 logger.info(f"Dataset loaded {self.data.shape[0]} rows successfully from {path}")
#
# File c:\Users\suluc\Desktop\autonomous-data-science-agent\notebooks\..\app\tools\data_loader.py:30, in DatasetLoader.validate_file(self, path)
# ...
